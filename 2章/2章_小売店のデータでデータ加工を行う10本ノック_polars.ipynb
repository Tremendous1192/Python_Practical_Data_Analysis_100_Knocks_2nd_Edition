# %%
# Google Driveと接続を行います。これを行うことで、Driveにあるデータにアクセスできるようになります。
# 下記セルを実行すると、Googleアカウントのログインを求められますのでログインしてください。
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# 作業フォルダへの移動を行います。
# 人によって作業場所がことなるので、その場合作業場所を変更してください。
#import os 
#os.chdir('/content/drive/MyDrive/100knock-data_analytics/2章') #ここを変更。

# %% [markdown]
# # ２章　小売店のデータでデータ加工を行う１０本ノック
#
# 本章では、ある小売店の売上履歴と顧客台帳データを用いて、データ分析の素地となる「データの加工」を習得することが目的です。
# 実際の現場データは手入力のExcel等、決して綺麗なデータではない事が多いため、
# データの揺れや整合性の担保など、汚いデータを取り扱うデータ加工を主体に進めて行きます。

# %% [markdown]
# ### ノック１１：データを読み込んでみよう

# %%
import polars as pl
# 列表示を省略しない
pl.Config.set_tbl_cols(-1)
# 行の表示を省略しない
pl.Config.set_tbl_rows(-1)
# Out:
# polars.config.Config

# %%
uriage_data = pl.read_csv("uriage.csv")
uriage_data.head()
# Out:
# shape: (5, 4)
# ┌─────────────────────┬───────────┬────────────┬───────────────┐
# │ purchase_date       ┆ item_name ┆ item_price ┆ customer_name │
# │ ---                 ┆ ---       ┆ ---        ┆ ---           │
# │ str                 ┆ str       ┆ i64        ┆ str           │
# ╞═════════════════════╪═══════════╪════════════╪═══════════════╡
# │ 2019-06-13 18:02:34 ┆ 商品A     ┆ 100        ┆ 深井菜々美    │
# │ 2019-07-13 13:05:29 ┆ 商 品 S   ┆ null       ┆ 浅田賢二      │
# │ 2019-05-11 19:42:07 ┆ 商 品 a   ┆ null       ┆ 南部慶二      │
# │ 2019-02-12 23:40:45 ┆ 商品Z     ┆ 2600       ┆ 麻生莉緒      │
# │ 2019-04-22 03:09:35 ┆ 商品a     ┆ null       ┆ 平田鉄二      │
# └─────────────────────┴───────────┴────────────┴───────────────┘

# %%
kokyaku_data = pl.read_excel("kokyaku_daicho.xlsx")
kokyaku_data.head()
# Out:
# shape: (5, 5)
# ┌─────────────┬─────────────────┬──────┬────────────────────────────┬────────────┐
# │ 顧客名      ┆ かな            ┆ 地域 ┆ メールアドレス             ┆ 登録日     │
# │ ---         ┆ ---             ┆ ---  ┆ ---                        ┆ ---        │
# │ str         ┆ str             ┆ str  ┆ str                        ┆ str        │
# ╞═════════════╪═════════════════╪══════╪════════════════════════════╪════════════╡
# │ 須賀ひとみ  ┆ すが ひとみ     ┆ H市  ┆ suga_hitomi@example.com    ┆ 2018/01/04 │
# │ 岡田　 敏也 ┆ おかだ としや   ┆ E市  ┆ okada_toshiya@example.com  ┆ 42782      │
# │ 芳賀 希     ┆ はが のぞみ     ┆ A市  ┆ haga_nozomi@example.com    ┆ 2018/01/07 │
# │ 荻野  愛    ┆ おぎの あい     ┆ F市  ┆ ogino_ai@example.com       ┆ 42872      │
# │ 栗田 憲一   ┆ くりた けんいち ┆ E市  ┆ kurita_kenichi@example.com ┆ 43127      │
# └─────────────┴─────────────────┴──────┴────────────────────────────┴────────────┘

# %% [markdown]
# ### ノック１２：データの揺れを見てみよう

# %%
uriage_data["item_name"].head()
# Out:
# shape: (10,)
# Series: 'item_name' [str]
# [
# 	"商品A"
# 	"商 品 S"
# 	"商 品 a"
# 	"商品Z"
# 	"商品a"
# 	"商品S"
# 	"商品 a"
# 	"商品V"
# 	"商品O"
# 	"商品A"
# ]

# %%
uriage_data["item_price"].head()
# Out:
# shape: (10,)
# Series: 'item_price' [i64]
# [
# 	100
# 	null
# 	null
# 	2600
# 	null
# 	1900
# 	null
# 	2200
# 	1500
# 	100
# ]

# %% [markdown]
# ### ノック１３：データに揺れがあるまま集計しよう

# %%
uriage_data = (
    uriage_data
    .replace("purchase_date", uriage_data["purchase_date"].str.strptime(dtype = pl.Datetime, format = "%Y-%m-%d %H:%M:%S"))
    .with_columns([uriage_data["purchase_date"].dt.strftime("%Y%m").alias("purchase_month")])
)

import polars.selectors as cs
res = uriage_data.pivot(values = cs.numeric(), index = "purchase_month", columns = "item_name", aggregate_function = "count")
res
# Out:
# C:\Users\treme\AppData\Local\Temp\ipykernel_8572\4206482639.py:3: DeprecationWarning: `replace` is deprecated. DataFrame.replace is deprecated and will be removed in a future version. Please use
#     df = df.with_columns(new_column.alias(column_name))
# instead.
#   .replace("purchase_date", uriage_data["purchase_date"].str.strptime(dtype = pl.Datetime, format = "%Y-%m-%d %H:%M:%S"))
# shape: (7, 100)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ pur ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  ┆ 商  │
# │ cha ┆ 品A ┆ 品  ┆ 品  ┆ 品Z ┆ 品a ┆ 品S ┆ 品  ┆ 品V ┆ 品O ┆ 品U ┆ 品L ┆ 品V ┆ 品O ┆ 品C ┆ 品I ┆ 品r ┆ 品X ┆ 品  ┆ 品R ┆ 品P ┆ 品Q ┆ 品y ┆ 品  ┆ 品N ┆ 品W ┆ 品E ┆ 品K ┆ 品B ┆ 品F ┆ 品s ┆ 品W ┆ 品  ┆ 品F ┆ 品D ┆ 品M ┆ 品Y ┆ 品U ┆ 品H ┆ 品T ┆ 品J ┆ 品O ┆ 品E ┆ 品Q ┆ 品S ┆ 品M ┆ 品T ┆ 品G ┆ 品G ┆ 品P ┆ 品E ┆ 品N ┆ 品Y ┆ 品  ┆ 品  ┆ 品  ┆ 品V ┆ 品D ┆ 品A ┆ 品  ┆ 品  ┆ 品K ┆ 品T ┆ 品  ┆ 品  ┆ 品X ┆ 品H ┆ 品C ┆ 品  ┆ 品  ┆ 品  ┆ 品v ┆ 品p ┆ 品i ┆ 品  ┆ 品  ┆ 品  ┆ 品s ┆ 品l ┆ 品t ┆ 品k ┆ 品g ┆ 品o ┆ 品  ┆ 品  ┆ 品M ┆ 品j ┆ 品d ┆ 品  ┆ 品  ┆ 品  ┆ 品c ┆ 品  ┆ 品e ┆ 品x ┆ 品I ┆ 品W ┆ 品X ┆ 品  ┆ 品P │
# │ se_ ┆ --- ┆ S   ┆ a   ┆ --- ┆ --- ┆ --- ┆ a   ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ g   ┆ --- ┆ --- ┆ --- ┆ --- ┆ A   ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ n   ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆
┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ J   ┆ V   ┆ K   ┆ --- ┆ --- ┆ --- ┆ F   ┆ H   ┆ --- ┆ --- ┆ X   ┆ Q   ┆ --- ┆ --- ┆ --- ┆ B   ┆ O   ┆ T   ┆ --- ┆ --- ┆ --- ┆ w   ┆ s   ┆ q   ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ R   ┆ S   ┆ --- ┆ --- ┆ --- ┆ I   ┆ E   ┆ o   ┆ --- ┆ v   ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ M   ┆ --- │
# │ mon ┆ i64 ┆ --- ┆ --- ┆ i64 ┆ i64 ┆ i64 ┆ --- ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ --- ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ --- ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ --- ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ --- ┆ --- ┆ --- ┆ i64 ┆ i64 ┆ i64 ┆ --- ┆ --- ┆ i64 ┆ i64 ┆ --- ┆ --- ┆ i64 ┆ i64 ┆ i64 ┆ --- ┆ --- ┆ --- ┆ i64 ┆ i64 ┆ i64 ┆ --- ┆ --- ┆ --- ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ --- ┆ --- ┆ i64 ┆ i64 ┆ i64 ┆ --- ┆ --- ┆ --- ┆ i64 ┆ --- ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ --- ┆ i64 │
# │ th  ┆     ┆ i64 ┆ i64 ┆     ┆     ┆     ┆ i64 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ i64 ┆     ┆     ┆     ┆     ┆ i64 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ i64 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ i64 ┆ i64 ┆ i64 ┆     ┆     ┆     ┆ i64 ┆ i64 ┆     ┆     ┆ i64 ┆ i64 ┆     ┆     ┆     ┆ i64 ┆ i64 ┆ i64 ┆     ┆     ┆     ┆ i64 ┆ i64 ┆ i64 ┆     ┆     ┆     ┆     ┆     ┆     ┆ i64 ┆ i64 ┆     ┆     ┆     ┆ i64 ┆ i64 ┆ i64 ┆     ┆ i64 ┆     ┆     ┆     ┆     ┆     ┆ i64 ┆     │
# │ --- ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# │ str ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     │
# ╞═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╡
# │ 201 ┆ 200 ┆ nul ┆ nul ┆ nul ┆ nul ┆ 342 ┆ nul ┆ 330 ┆ 195 ┆ 210 ┆ 144 ┆ nul ┆ 150 ┆ 240 ┆ 126 ┆ nul ┆ 240 ┆ 700 ┆ 270 ┆ 240 ┆ 238 ┆ nul ┆ 100 ┆ 154 ┆ 253 ┆ nul ┆ 154 ┆ 240 ┆ 960 ┆ nul ┆ nul ┆ nul ┆ nul ┆ 720 ┆ 195 ┆ 300 ┆ 294 ┆ 880 ┆ 220 ┆ 200 ┆ nul ┆ 650 ┆ nul ┆ nul ┆ nul ┆ nul ┆ 770 ┆ 700 ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ 0   ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ 800 ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ 300 ┆ nul ┆ nul ┆ nul ┆ nul ┆ 160 ┆ 900 ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ 240 ┆ nul ┆ 230 ┆ nul ┆ nul ┆ nul │
# │ 906 ┆ 0   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 00  ┆ l   ┆ 00  ┆ 00  ┆ 0   ┆ 00  ┆ l   ┆ 0   ┆ 0   ┆ 00  ┆ l   ┆ 00  ┆     ┆ 00  ┆ 00  ┆ 00  ┆ l   ┆     ┆ 00  ┆ 00  ┆ l   ┆ 00  ┆ 0   ┆ 0   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 0   ┆ 00  ┆ 00  ┆ 00  ┆ 0   ┆ 00  ┆ 00  ┆ l   ┆ 0   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 0   ┆     ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆     ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆     ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆     ┆ l   ┆ l   ┆ l   ┆ l   ┆ 0   ┆     ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 0   ┆ l   ┆ 0   ┆ l   ┆ l   ┆ l   │
# │ 201 ┆ 160 ┆ 0   ┆ nul ┆ nul ┆ nul ┆ 380 ┆ nul ┆ 528 ┆ 255 ┆ nul ┆ 204 ┆ nul ┆ 150 ┆ 450 ┆ 135 ┆ 180 ┆ 384 ┆ nul ┆ 252 ┆ 384 ┆ 187 ┆ nul ┆ nul ┆ 182 ┆ 322 ┆ 500 ┆ 990 ┆ 360 ┆ 960 ┆ nul ┆ nul ┆ nul ┆ nul ┆
┆ nul ┆ nul ┆ nul ┆ nul ┆ 285 ┆ nul ┆ 418 ┆ 270 ┆ nul ┆ 192 ┆ nul ┆ 150 ┆ 510 ┆ 135 ┆ nul ┆ 240 ┆ nul ┆ 360 ┆ 208 ┆ 255 ┆ nul ┆ nul ┆ 210 ┆ 276 ┆ nul ┆ 165 ┆ 160 ┆ 780 ┆ 190 ┆ nul ┆ 140 ┆ nul ┆ 600 ┆ 195 ┆ 200 ┆ 126 ┆ 104 ┆ 280 ┆ 160 ┆ nul ┆ 650 ┆ nul ┆ nul ┆ nul ┆ nul ┆ 700 ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ 220 ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ 200 ┆ nul ┆ nul ┆ 480 ┆ 800 ┆ nul ┆ nul ┆ 150 ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ 120 ┆ nul ┆ 110 ┆ nul ┆ 150 ┆ nul ┆ 190 ┆ nul ┆ nul ┆ nul ┆ 900 ┆ nul ┆ nul ┆ 300 ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ nul ┆ 130 ┆ 160 │
# │ 901 ┆ 0   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 00  ┆ l   ┆ 00  ┆ 00  ┆ l   ┆ 00  ┆ l   ┆ 0   ┆ 0   ┆ 00  ┆ l   ┆ 00  ┆ l   ┆ 00  ┆ 00  ┆ 00  ┆ l   ┆ l   ┆ 00  ┆ 00  ┆ l   ┆ 00  ┆ 0   ┆ 0   ┆ 0   ┆ l   ┆ 0   ┆ l   ┆ 0   ┆ 00  ┆ 00  ┆ 00  ┆ 00  ┆ 00  ┆ 00  ┆ l   ┆ 0   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 0   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 0   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 0   ┆ l   ┆ l   ┆ 0   ┆     ┆ l   ┆ l   ┆ 0   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 0   ┆ l   ┆ 0   ┆ l   ┆ 0   ┆ l   ┆ 0   ┆ l   ┆ l   ┆ l   ┆     ┆ l   ┆ l   ┆     ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ l   ┆ 0   ┆ 0   │
# └─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┘

# %% [markdown]
# ### ノック１４：商品名の揺れを補正しよう

# %%
print( len( uriage_data["item_name"].unique() ) )
# Out:
# 99

# %%
uriage_data["item_name"].unique().sort().head()
# 商品名の揺れ
# 半角スペース "  商品W"
# 半角スペース 2個連続 "商  品O"
# 小文字のアルファベット " 商 品 n"
# Out:
# shape: (10,)
# Series: 'item_name' [str]
# [
# 	"  商品W"
# 	" 商 品 n"
# 	" 商品E"
# 	" 商品M"
# 	" 商品P"
# 	" 商品S"
# 	" 商品W"
# 	" 商品X"
# 	"商  品O"
# 	"商  品Q"
# ]

# %%
uriage_data = (
    uriage_data
    .replace("item_name",
             uriage_data["item_name"]
             .str.to_uppercase()
             .str.replace_all("　", "")
             .str.replace_all(" ", ""))
)

uriage_data.sort(by = ["item_name"]).head(10)
# Out:
# C:\Users\treme\AppData\Local\Temp\ipykernel_8572\1370451766.py:3: DeprecationWarning: `replace` is deprecated. DataFrame.replace is deprecated and will be removed in a future version. Please use
#     df = df.with_columns(new_column.alias(column_name))
# instead.
#   .replace("item_name",
# shape: (10, 5)
# ┌─────────────────────┬───────────┬────────────┬───────────────┬────────────────┐
# │ purchase_date       ┆ item_name ┆ item_price ┆ customer_name ┆ purchase_month │
# │ ---                 ┆ ---       ┆ ---        ┆ ---           ┆ ---            │
# │ datetime[μs]        ┆ str       ┆ i64        ┆ str           ┆ str            │
# ╞═════════════════════╪═══════════╪════════════╪═══════════════╪════════════════╡
# │ 2019-06-13 18:02:34 ┆ 商品A     ┆ 100        ┆ 深井菜々美    ┆ 201906         │
# │ 2019-05-11 19:42:07 ┆ 商品A     ┆ null       ┆ 南部慶二      ┆ 201905         │
# │ 2019-04-22 03:09:35 ┆ 商品A     ┆ null       ┆ 平田鉄二      ┆ 201904         │
# │ 2019-05-18 19:16:53 ┆ 商品A     ┆ null       ┆ 深井照生      ┆ 201905         │
# │ 2019-01-28 10:47:03 ┆ 商品A     ┆ 100        ┆ 大地礼子      ┆ 201901         │
# │ 2019-06-11 12:57:24 ┆ 商品A     ┆ null       ┆ 黄川田博之    ┆ 201906         │
# │ 2019-06-29 10:01:52 ┆ 商品A     ┆ 100        ┆ 石田佑        ┆ 201906         │
# │ 2019-01-12 03:26:36 ┆ 商品A     ┆ 100        ┆ 小平陽子      ┆ 201901         │
# │ 2019-02-11 17:00:37 ┆ 商品A     ┆ 100        ┆ 原口俊二      ┆ 201902         │
# │ 2019-06-14 09:08:17 ┆ 商品A     ┆ 100        ┆ 深井菜々美    ┆ 201906         │
# └─────────────────────┴───────────┴────────────┴───────────────┴────────────────┘

# %% [markdown]
# ### ノック１５：金額欠損値の補完をしよう

# %%
uriage_data.select(pl.all().null_count())
# Out:
# shape: (1, 5)
# ┌───────────────┬───────────┬────────────┬───────────────┬────────────────┐
# │ purchase_date ┆ item_name ┆ item_price ┆ customer_name ┆ purchase_month │
# │ ---           ┆ ---       ┆ ---        ┆ ---           ┆ ---            │
# │ u32           ┆ u32       ┆ u32        ┆ u32           ┆ u32            │
# ╞═══════════════╪═══════════╪════════════╪═══════════════╪════════════════╡
# │ 0             ┆ 0         ┆ 387        ┆ 0             ┆ 0              │
# └───────────────┴───────────┴────────────┴───────────────┴────────────────┘

# %%
# 製品価格の欠損値を埋めるために、{製品名: 製品価格}の辞書型を作成する
uriage_drop_null = uriage_data[["item_name", "item_price"]]\
    .sort(by = ["item_price"], descending = True)\
        .drop_nulls(subset = ["item_price"])\
            .unique(subset = ["item_name"])

uriage_dict = {}
for row in range(len(uriage_drop_null)):
    uriage_dict[uriage_drop_null[row, 0]] = uriage_drop_null[row, 1]
uriage_dict

del uriage_drop_null

# %%
uriage_drop_null = uriage_data[["item_name", "item_price"]]\
    .sort(by = ["item_price"], descending = True)\
        .drop_nulls(subset = ["item_price"])\
            .unique(subset = ["item_name"])
uriage_dict = {}
for row in range(len(uriage_drop_null)):
    uriage_dict[uriage_drop_null[row, 0]] = uriage_drop_null[row, 1]
uriage_dict
# Out:
# {'商品L': 1200,
#  '商品V': 2200,
#  '商品U': 2100,
#  '商品Y': 2500,
#  '商品G': 700,
#  '商品Q': 1700,
#  '商品B': 200,
#  '商品J': 1000,
#  '商品R': 1800,
#  '商品X': 2400,
#  '商品W': 2300,
#  '商品D': 400,
#  '商品Z': 2600,
#  '商品O': 1500,
#  '商品S': 1900,
#  '商品N': 1400,
#  '商品P': 1600,
#  '商品A': 100,
#  '商品H': 800,
#  '商品C': 300,
#  '商品E': 500,
#  '商品K': 1100,
#  '商品I': 900,
#  '商品F': 600,
#  '商品T': 2000,
#  '商品M': 1300}

# %%
for trg in uriage_data["item_name"].sort().unique().to_list():
    (
        print(trg
              + "の最大額:" + str( uriage_data.filter( pl.col("item_name") == trg )["item_price"].max() )
              + "\tの最小額: " + str(uriage_data.filter( pl.col("item_name") == trg )["item_price"].min()) )
    )
# Out:
# 商品Uの最大額:2100	の最小額: 2100
# 商品Jの最大額:1000	の最小額: 1000
# 商品Lの最大額:1200	の最小額: 1200
# 商品Kの最大額:1100	の最小額: 1100
# 商品Wの最大額:2300	の最小額: 2300
# 商品Oの最大額:1500	の最小額: 1500
# 商品Mの最大額:1300	の最小額: 1300
# 商品Zの最大額:2600	の最小額: 2600
# 商品Yの最大額:2500	の最小額: 2500
# 商品Aの最大額:100	の最小額: 100
# 商品Cの最大額:300	の最小額: 300
# 商品Sの最大額:1900	の最小額: 1900
# 商品Dの最大額:400	の最小額: 400
# 商品Pの最大額:1600	の最小額: 1600
# 商品Tの最大額:2000	の最小額: 2000
# 商品Fの最大額:600	の最小額: 600
# 商品Iの最大額:900	の最小額: 900
# 商品Nの最大額:1400	の最小額: 1400
# 商品Eの最大額:500	の最小額: 500
# 商品Gの最大額:700	の最小額: 700
# 商品Xの最大額:2400	の最小額: 2400
# 商品Rの最大額:1800	の最小額: 1800
# 商品Bの最大額:200	の最小額: 200
# 商品Vの最大額:2200	の最小額: 2200
# 商品Hの最大額:800	の最小額: 800
# 商品Qの最大額:1700	の最小額: 1700

# %% [markdown]
# ### ノック１６：顧客名の揺れを補正しよう

# %%
kokyaku_data["顧客名"].head()
# Out:
# shape: (10,)
# Series: '顧客名' [str]
# [
# 	"須賀ひとみ"
# 	"岡田　 敏也"
# 	"芳賀 希"
# 	"荻野  愛"
# 	"栗田 憲一"
# 	"梅沢 麻緒"
# 	"相原 ひとり"
# 	"新村 丈史"
# 	"石川  まさみ"
# 	"小栗 正義"
# ]

# %%
uriage_data["customer_name"].head()
# Out:
# shape: (10,)
# Series: 'customer_name' [str]
# [
# 	"深井菜々美"
# 	"浅田賢二"
# 	"南部慶二"
# 	"麻生莉緒"
# 	"平田鉄二"
# 	"堀江佑"
# 	"深井照生"
# 	"牧田玲那"
# 	"堀北雅彦"
# 	"大地礼子"
# ]

# %%
#DeprecationWarning: `replace` is deprecated. DataFrame.replace is deprecated and will be removed in a future version. Please use
#    df = df.with_columns(new_column.alias(column_name))
#kokyaku_data = (
#    kokyaku_data.replace("顧客名",
#                         kokyaku_data["顧客名"].str.replace_all("　", "").str.replace_all(" ", ""))
#)

kokyaku_data = (
    kokyaku_data.with_columns(
        kokyaku_data["顧客名"].str.replace_all("　", "").str.replace_all(" ", "").alias("顧客名"))
)
kokyaku_data["顧客名"].head(n = 5)
# Out:
# shape: (5,)
# Series: '顧客名' [str]
# [
# 	"須賀ひとみ"
# 	"岡田敏也"
# 	"芳賀希"
# 	"荻野愛"
# 	"栗田憲一"
# ]

# %% [markdown]
# ### ノック１７：日付の揺れを補正しよう

# %%
flg_is_serial = kokyaku_data["登録日"].cast(pl.Int64, strict = False)
len( flg_is_serial.drop_nulls() )
# Out:
# 22

# %%
#flg_is_serial = kokyaku_data["登録日"].astype("str").str.isdigit()
#flg_is_serial.sum()

# %%
#fromSerial = pd.to_timedelta(kokyaku_data.loc[flg_is_serial, "登録日"].astype("float") - 2, unit="D") + pd.to_datetime('1900/1/1')
#fromSerial

# %%
#fromString = pd.to_datetime(kokyaku_data.loc[~flg_is_serial, "登録日"])
#fromString

# %%
#kokyaku_data["登録日"] = pd.concat([fromSerial, fromString])
#kokyaku_data

# %%
#kokyaku_data["登録年月"] = kokyaku_data["登録日"].dt.strftime("%Y%m")
#rslt = kokyaku_data.groupby("登録年月").count()["顧客名"]
#print(rslt)
#print(len(kokyaku_data))

# %%
from datetime import datetime, timedelta

# Excelの日付形式をPythonのdatetime型に変換する関数を定義します。
def convert_excel_date_to_datetime(excel_date):
    return datetime(1899, 12, 30) + timedelta(days=int(excel_date))

# 日付と数字が混在したSeriesを、Excel書式の日付にに変換する
converted_date = (
    kokyaku_data["登録日"].cast(pl.Utf8)
    .map_elements(lambda x: convert_excel_date_to_datetime(x)
                  if x.isdigit() else datetime.strptime(x, "%Y/%m/%d"), return_dtype = pl.Date)
)

converted_date.head(n = 5)

kokyaku_data = (
    kokyaku_data.with_columns(
        converted_date.alias("登録日")
    )
)

# %%
kokyaku_data = (
    kokyaku_data.with_columns(
        converted_date.dt.strftime("%Y%m").alias("登録年月")
    )
)

rslt = kokyaku_data.group_by(by = "登録年月").agg( pl.col("顧客名").count() ).sort(by = "登録年月")
print(rslt)
print(len(kokyaku_data))
# Out:
# shape: (15, 2)
# ┌──────────┬────────┐
# │ 登録年月 ┆ 顧客名 │
# │ ---      ┆ ---    │
# │ str      ┆ u32    │
# ╞══════════╪════════╡
# │ 201701   ┆ 15     │
# │ 201702   ┆ 11     │
# │ 201703   ┆ 14     │
# │ 201704   ┆ 15     │
# │ 201705   ┆ 14     │
# │ 201706   ┆ 13     │
# │ 201707   ┆ 17     │
# │ 201801   ┆ 13     │
# │ 201802   ┆ 15     │
# │ 201803   ┆ 17     │
# │ 201804   ┆ 5      │
# │ 201805   ┆ 19     │
# │ 201806   ┆ 13     │
# │ 201807   ┆ 17     │
# │ 201904   ┆ 2      │
# └──────────┴────────┘
# 200

# %%
flg_is_serial = kokyaku_data["登録日"].cast(pl.Int64, strict = False)
len( flg_is_serial.drop_nulls() )
# Out:
# 200

# %% [markdown]
# ### ノック１８：顧客名をキーに２つのデータを結合(ジョイン)しよう

# %%
join_data = (
    uriage_data
    .rename(mapping = {"customer_name": "顧客名"})
    .join(other = kokyaku_data, on="顧客名", how="left")
)
join_data.head()
# Out:
# shape: (5, 10)
# ┌──────────┬──────────┬─────────┬─────────┬─────────┬─────────┬──────┬─────────┬─────────┬─────────┐
# │ purchase ┆ item_nam ┆ item_pr ┆ 顧客名  ┆ purchas ┆ かな    ┆ 地域 ┆ メール  ┆ 登録日  ┆ 登録年  │
# │ _date    ┆ e        ┆ ice     ┆ ---     ┆ e_month ┆ ---     ┆ ---  ┆ アドレ  ┆ ---     ┆ 月      │
# │ ---      ┆ ---      ┆ ---     ┆ str     ┆ ---     ┆ str     ┆ str  ┆ ス      ┆ datetim ┆ ---     │
# │ datetime ┆ str      ┆ i64     ┆         ┆ str     ┆         ┆      ┆ ---     ┆ e[μs]   ┆ str     │
# │ [μs]     ┆          ┆         ┆         ┆         ┆         ┆      ┆ str     ┆         ┆         │
# ╞══════════╪══════════╪═════════╪═════════╪═════════╪═════════╪══════╪═════════╪═════════╪═════════╡
# │ 2019-06- ┆ 商品A    ┆ 100     ┆ 深井菜  ┆ 201906  ┆ ふかい  ┆ C市  ┆ fukai_n ┆ 2017-01 ┆ 201701  │
# │ 13       ┆          ┆         ┆ 々美    ┆         ┆ ななみ  ┆      ┆ anami@e ┆ -26 00: ┆         │
# │ 18:02:34 ┆          ┆         ┆         ┆         ┆         ┆      ┆ xample. ┆ 00:00   ┆         │
# │          ┆          ┆         ┆         ┆         ┆         ┆      ┆ com     ┆         ┆         │
# │ 2019-07- ┆ 商品S    ┆ null    ┆ 浅田賢  ┆ 201907  ┆ あさだ  ┆ C市  ┆ asada_k ┆ 2018-04 ┆ 201804  │
# │ 13       ┆          ┆         ┆ 二      ┆         ┆ けんじ  ┆      ┆ enji@ex ┆ -07 00: ┆         │
# │ 13:05:29 ┆          ┆         ┆         ┆         ┆         ┆      ┆ ample.c ┆ 00:00   ┆         │
# │          ┆          ┆         ┆         ┆         ┆         ┆      ┆ om      ┆         ┆         │
# │ 2019-05- ┆ 商品A    ┆ null    ┆ 南部慶  ┆ 201905  ┆ なんぶ  ┆ A市  ┆ nannbu_ ┆ 2018-06 ┆ 201806  │
# │ 11       ┆          ┆         ┆ 二      ┆         ┆ けいじ  ┆      ┆ keiji@e ┆ -19 00: ┆         │
# │ 19:42:07 ┆          ┆         ┆         ┆         ┆         ┆      ┆ xample. ┆ 00:00   ┆         │
# │          ┆          ┆         ┆         ┆         ┆         ┆      ┆ com     ┆         ┆         │
# │ 2019-02- ┆ 商品Z    ┆ 2600    ┆ 麻生莉  ┆ 201902  ┆ あそう  ┆ D市  ┆ asou_ri ┆ 2018-07 ┆ 201807  │
# │ 12       ┆          ┆         ┆ 緒      ┆         ┆ りお    ┆      ┆ o@examp ┆ -22 00: ┆         │
# │ 23:40:45 ┆          ┆         ┆         ┆         ┆         ┆      ┆ le.com  ┆ 00:00   ┆         │
# │ 2019-04- ┆ 商品A    ┆ null    ┆ 平田鉄  ┆ 201904  ┆ ひらた  ┆ D市  ┆ hirata_ ┆ 2017-06 ┆ 201706  │
# │ 22       ┆          ┆         ┆ 二      ┆         ┆ てつじ  ┆      ┆ tetsuji ┆ -07 00: ┆         │
# │ 03:09:35 ┆          ┆         ┆         ┆         ┆         ┆      ┆ @exampl ┆ 00:00   ┆         │
# │          ┆          ┆         ┆         ┆         ┆         ┆      ┆ e.com   ┆         ┆         │
# └──────────┴──────────┴─────────┴─────────┴─────────┴─────────┴──────┴─────────┴─────────┴─────────┘

# %% [markdown]
# ### ノック１９：クレンジングしたデータをダンプしよう

# %%
dump_data = join_data[["purchase_date", "purchase_month", "item_name", "item_price", "顧客名", "かな", "地域", "メールアドレス", "登録日"]]
dump_data.head()
# Out:
# shape: (5, 9)
# ┌───────────┬───────────┬───────────┬───────────┬──────────┬──────────┬──────┬──────────┬──────────┐
# │ purchase_ ┆ purchase_ ┆ item_name ┆ item_pric ┆ 顧客名   ┆ かな     ┆ 地域 ┆ メールア ┆ 登録日   │
# │ date      ┆ month     ┆ ---       ┆ e         ┆ ---      ┆ ---      ┆ ---  ┆ ドレス   ┆ ---      │
# │ ---       ┆ ---       ┆ str       ┆ ---       ┆ str      ┆ str      ┆ str  ┆ ---      ┆ datetime │
# │ datetime[ ┆ str       ┆           ┆ i64       ┆          ┆          ┆      ┆ str      ┆ [μs]     │
# │ μs]       ┆           ┆           ┆           ┆          ┆          ┆      ┆          ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪══════════╪══════════╪══════╪══════════╪══════════╡
# │ 2019-06-1 ┆ 201906    ┆ 商品A     ┆ 100       ┆ 深井菜々 ┆ ふかい   ┆ C市  ┆ fukai_na ┆ 2017-01- │
# │ 3         ┆           ┆           ┆           ┆ 美       ┆ ななみ   ┆      ┆ nami@exa ┆ 26       │
# │ 18:02:34  ┆           ┆           ┆           ┆          ┆          ┆      ┆ mple.com ┆ 00:00:00 │
# │ 2019-07-1 ┆ 201907    ┆ 商品S     ┆ null      ┆ 浅田賢二 ┆ あさだ   ┆ C市  ┆ asada_ke ┆ 2018-04- │
# │ 3         ┆           ┆           ┆           ┆          ┆ けんじ   ┆      ┆ nji@exam ┆ 07       │
# │ 13:05:29  ┆           ┆           ┆           ┆          ┆          ┆      ┆ ple.com  ┆ 00:00:00 │
# │ 2019-05-1 ┆ 201905    ┆ 商品A     ┆ null      ┆ 南部慶二 ┆ なんぶ   ┆ A市  ┆ nannbu_k ┆ 2018-06- │
# │ 1         ┆           ┆           ┆           ┆          ┆ けいじ   ┆      ┆ eiji@exa ┆ 19       │
# │ 19:42:07  ┆           ┆           ┆           ┆          ┆          ┆      ┆ mple.com ┆ 00:00:00 │
# │ 2019-02-1 ┆ 201902    ┆ 商品Z     ┆ 2600      ┆ 麻生莉緒 ┆ あそう   ┆ D市  ┆ asou_rio ┆ 2018-07- │
# │ 2         ┆           ┆           ┆           ┆          ┆ りお     ┆      ┆ @example ┆ 22       │
# │ 23:40:45  ┆           ┆           ┆           ┆          ┆          ┆      ┆ .com     ┆ 00:00:00 │
# │ 2019-04-2 ┆ 201904    ┆ 商品A     ┆ null      ┆ 平田鉄二 ┆ ひらた   ┆ D市  ┆ hirata_t ┆ 2017-06- │
# │ 2         ┆           ┆           ┆           ┆          ┆ てつじ   ┆      ┆ etsuji@e ┆ 07       │
# │ 03:09:35  ┆           ┆           ┆           ┆          ┆          ┆      ┆ xample.c ┆ 00:00:00 │
# │           ┆           ┆           ┆           ┆          ┆          ┆      ┆ om       ┆          │
# └───────────┴───────────┴───────────┴───────────┴──────────┴──────────┴──────┴──────────┴──────────┘

# %%
dump_data.write_csv("dump_data.csv")

# %% [markdown]
# ### ノック２０：データを集計しよう

# %%
import_data = pl.read_csv("dump_data.csv")
import_data.head()
# Out:
# shape: (5, 9)
# ┌───────────┬───────────┬───────────┬───────────┬──────────┬──────────┬──────┬──────────┬──────────┐
# │ purchase_ ┆ purchase_ ┆ item_name ┆ item_pric ┆ 顧客名   ┆ かな     ┆ 地域 ┆ メールア ┆ 登録日   │
# │ date      ┆ month     ┆ ---       ┆ e         ┆ ---      ┆ ---      ┆ ---  ┆ ドレス   ┆ ---      │
# │ ---       ┆ ---       ┆ str       ┆ ---       ┆ str      ┆ str      ┆ str  ┆ ---      ┆ str      │
# │ str       ┆ i64       ┆           ┆ i64       ┆          ┆          ┆      ┆ str      ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪══════════╪══════════╪══════╪══════════╪══════════╡
# │ 2019-06-1 ┆ 201906    ┆ 商品A     ┆ 100       ┆ 深井菜々 ┆ ふかい   ┆ C市  ┆ fukai_na ┆ 2017-01- │
# │ 3T18:02:3 ┆           ┆           ┆           ┆ 美       ┆ ななみ   ┆      ┆ nami@exa ┆ 26T00:00 │
# │ 4.000000  ┆           ┆           ┆           ┆          ┆          ┆      ┆ mple.com ┆ :00.0000 │
# │           ┆           ┆           ┆           ┆          ┆          ┆      ┆          ┆ 00       │
# │ 2019-07-1 ┆ 201907    ┆ 商品S     ┆ null      ┆ 浅田賢二 ┆ あさだ   ┆ C市  ┆ asada_ke ┆ 2018-04- │
# │ 3T13:05:2 ┆           ┆           ┆           ┆          ┆ けんじ   ┆      ┆ nji@exam ┆ 07T00:00 │
# │ 9.000000  ┆           ┆           ┆           ┆          ┆          ┆      ┆ ple.com  ┆ :00.0000 │
# │           ┆           ┆           ┆           ┆          ┆          ┆      ┆          ┆ 00       │
# │ 2019-05-1 ┆ 201905    ┆ 商品A     ┆ null      ┆ 南部慶二 ┆ なんぶ   ┆ A市  ┆ nannbu_k ┆ 2018-06- │
# │ 1T19:42:0 ┆           ┆           ┆           ┆          ┆ けいじ   ┆      ┆ eiji@exa ┆ 19T00:00 │
# │ 7.000000  ┆           ┆           ┆           ┆          ┆          ┆      ┆ mple.com ┆ :00.0000 │
# │           ┆           ┆           ┆           ┆          ┆          ┆      ┆          ┆ 00       │
# │ 2019-02-1 ┆ 201902    ┆ 商品Z     ┆ 2600      ┆ 麻生莉緒 ┆ あそう   ┆ D市  ┆ asou_rio ┆ 2018-07- │
# │ 2T23:40:4 ┆           ┆           ┆           ┆          ┆ りお     ┆      ┆ @example ┆ 22T00:00 │
# │ 5.000000  ┆           ┆           ┆           ┆          ┆          ┆      ┆ .com     ┆ :00.0000 │
# │           ┆           ┆           ┆           ┆          ┆          ┆      ┆          ┆ 00       │
# │ 2019-04-2 ┆ 201904    ┆ 商品A     ┆ null      ┆ 平田鉄二 ┆ ひらた   ┆ D市  ┆ hirata_t ┆ 2017-06- │
# │ 2T03:09:3 ┆           ┆           ┆           ┆          ┆ てつじ   ┆      ┆ etsuji@e ┆ 07T00:00 │
# │ 5.000000  ┆           ┆           ┆           ┆          ┆          ┆      ┆ xample.c ┆ :00.0000 │
# │           ┆           ┆           ┆           ┆          ┆          ┆      ┆ om       ┆ 00       │
# └───────────┴───────────┴───────────┴───────────┴──────────┴──────────┴──────┴──────────┴──────────┘

# %%
byItem = (
    import_data
    .pivot(index = "purchase_month",
           columns = "item_name",
           values = "item_name",
           aggregate_function = "count",
           sort_columns = True)
           .sort(by = "purchase_month")
)
byItem
# Out:
# shape: (7, 27)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │
   ┆ 2   ┆ 1   ┆ 1   ┆ 4   ┆ 1   ┆ 1   ┆ 2   ┆ 2   ┆ 3   ┆ 1   ┆ 2   ┆ 5   ┆ 1   ┆ 3   ┆ 2   ┆ 4   ┆ 1   ┆ 6   ┆ nul ┆ 9   ┆ 1   ┆ 3   ┆ 4   ┆ 2   ┆ 3   ┆ 3   ┆ 2   ┆ nul ┆ 1   ┆ 3   ┆ 4   ┆ 3   ┆ 3   ┆ 1   ┆ 1   ┆ 1   ┆ 2   ┆ 2   ┆ nul ┆ 2   ┆ 3   ┆ 4   ┆ 2   ┆ 1   ┆ nul ┆ 1   ┆ 2   ┆ 1   ┆ 1   ┆ 4   ┆ 3   ┆ 4   ┆ 2   ┆ 3   ┆ 4   ┆ 3   ┆ 2   ┆ nul ┆ nul ┆ 4   ┆ 2   ┆ 4   ┆ 4   ┆ 2   ┆ nul ┆ 2   ┆ 4   ┆ 3   ┆ 4   ┆ 1   │
# │ 907 ┆     ┆ l   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l   ┆     ┆     ┆     ┆     ┆     ┆ l   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l   ┆     ┆     ┆     ┆     ┆     ┆ l   ┆     ┆ l   ┆ l   ┆ l   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l   ┆ l   ┆     ┆     ┆     ┆     ┆     ┆ l   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l   ┆     ┆     ┆     ┆     ┆     ┆ l   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l   ┆ l   ┆     ┆     ┆     ┆     ┆     ┆ l   ┆     ┆     ┆     ┆     ┆     │
# └─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┘

# %%
byRegion = (
    import_data
    .pivot(index = "purchase_month",
           columns = "地域",
           values = "地域",
           aggregate_function = "count",
           sort_columns = True)
           .sort(by = "purchase_month")
)
byRegion
# Out:
# shape: (7, 9)
# ┌────────────────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ purchase_month ┆ A市 ┆ B市 ┆ C市 ┆ D市 ┆ E市 ┆ F市 ┆ G市 ┆ H市 │
# │ ---            ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- │
# │ i64            ┆ u32 ┆ u32 ┆ u32 ┆ u32 ┆ u32 ┆ u32 ┆ u32 ┆ u32 │
# ╞════════════════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╡
# │ 201901         ┆ 59  ┆ 55  ┆ 72  ┆ 34  ┆ 49  ┆ 57  ┆ 49  ┆ 42  │
# │ 201902         ┆ 71  ┆ 46  ┆ 65  ┆ 48  ┆ 61  ┆ 52  ┆ 43  ┆ 63  │
# │ 201903         ┆ 64  ┆ 52  ┆ 57  ┆ 43  ┆ 52  ┆ 59  ┆ 51  ┆ 59  │
# │ 201904         ┆ 64  ┆ 48  ┆ 54  ┆ 45  ┆ 48  ┆ 58  ┆ 40  ┆ 52  │
# │ 201905         ┆ 57  ┆ 52  ┆ 68  ┆ 48  ┆ 59  ┆ 65  ┆ 35  ┆ 43  │
# │ 201906         ┆ 53  ┆ 47  ┆ 61  ┆ 30  ┆ 51  ┆ 51  ┆ 58  ┆ 58  │
# │ 201907         ┆ 76  ┆ 53  ┆ 61  ┆ 42  ┆ 54  ┆ 64  ┆ 47  ┆ 54  │
# └────────────────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┘

# %%
#away_data = pl.merge(uriage_data, kokyaku_data, left_on="customer_name", right_on="顧客名", how="right")
#away_data[away_data["purchase_date"].isnull()][["顧客名", "メールアドレス", "登録日"]]

away_data = (
    uriage_data
    .rename(mapping = {"customer_name": "顧客名"})
    .join(other = kokyaku_data, on="顧客名", how="left")
)
away_data.filter( pl.col("purchase_date").is_null() )[["顧客名", "メールアドレス", "登録日"]]
# Out:
# shape: (0, 3)
# ┌────────┬────────────────┬──────────────┐
# │ 顧客名 ┆ メールアドレス ┆ 登録日       │
# │ ---    ┆ ---            ┆ ---          │
# │ str    ┆ str            ┆ datetime[μs] │
# ╞════════╪════════════════╪══════════════╡
# └────────┴────────────────┴──────────────┘
